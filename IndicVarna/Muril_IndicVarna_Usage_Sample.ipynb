# %%
from transformers import pipeline

# %%
sentiment_predict = pipeline("text-classification", model="dynopii/muril-indicvarna-tiny-sentiment")
# Out:
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/950M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
sentiment_predict("हां जी")
# Out:
# [{'label': 'LABEL_2', 'score': 0.5206834077835083}]

# %%
sentiment_predict("नहीं जी")
# Out:
# [{'label': 'LABEL_0', 'score': 0.42674893140792847}]

# %%
# %%timeit
sentiment_predict("नहीं जी")
# Out:
# 68.8 ms ± 10.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
